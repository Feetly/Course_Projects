# %%
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-7-d9c82b37c377> in <module>
#       1 import numpy as np
#       2 import random
# ----> 3 from plotly.offline import iplot,init_notebook_mode
#       4 import matplotlib.pyplot as plt
#
# ModuleNotFoundError: No module named 'plotly'

# %%
a
# Out:
# array([0.      , 0.0625  , 0.125   , 0.25    , 0.3125  , 0.328125,
#        0.34375 , 0.375   , 0.5     , 0.75    , 1.      ])
